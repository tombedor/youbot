# %% [markdown]
# # Setup

# %% [markdown]
# ## pipeline config

# %%
CONFIG_CONTENT = """
[nlp]
lang = "en"
pipeline = ["llm_ner", "llm_rel"]

[components]

[components.llm_ner]
factory="llm"

[components.llm_ner.model]
@llm_models = "spacy.OpenLLaMA.v1"
name = "open_llama_7b_v2"

[components.llm_ner.task]
@llm_tasks = "spacy.NER.v3"
labels = ["PERSON", "ORG", "GPE", "LOC", "PRODUCT", "EVENT", "WORK_OF_ART", "DATE", "TIME", "PERCENT", "MONEY", "QUANTITY", "ORDINAL", "CARDINAL", "PET", "TECHNICAL_CONCEPT"]


[components.llm_rel]
factory = "llm"

[components.llm_rel.model]
@llm_models = "spacy.OpenLLaMA.v1"
name = "open_llama_7b_v2"

[components.llm_rel.task]
@llm_tasks = "spacy.REL.v1"
labels = ["is a romantic partner of", "is employed by", "is pet owner of", "lives in", "works on", "is a friend of", "has duration", "is a relative of"]
"""


with open('config.cfg', 'w') as f:
    f.write(CONFIG_CONTENT)
    
    
DATA_SOURCE_DIR = '/datasets/data_pkl'

# %% [markdown]
# ## install requirements

# %%
# !sudo apt-get update
# !sudo apt-get install libcairo2-dev libjpeg-dev libgif-dev -y
# Out:
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1581 B]
# Get:3 https://deb.nodesource.com/node_16.x focal InRelease [4583 B]
# Get:4 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease [18.1 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:6 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1201 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [3536 kB]
# Get:10 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [29.8 kB]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3595 kB]
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [1515 kB]
# Get:13 https://deb.nodesource.com/node_16.x focal/main amd64 Packages [776 B]
# Get:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal/main amd64 Packages [35.6 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1497 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [3686 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [32.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [4069 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [28.6 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [55.2 kB]
# Fetched 19.6 MB in 2s (8143 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libblkid-dev libblkid1 libcairo-script-interpreter2 libffi-dev
#   libfontconfig1-dev libfreetype-dev libfreetype6 libfreetype6-dev
#   libglib2.0-0 libglib2.0-bin libglib2.0-dev libglib2.0-dev-bin libice-dev
#   libjpeg-turbo8-dev libjpeg8-dev liblzo2-2 libmount-dev libmount1 libpcre16-3
#   libpcre2-16-0 libpcre2-32-0 libpcre2-dev libpcre2-posix2 libpcre3-dev
#   libpcre32-3 libpcrecpp0v5 libpixman-1-dev libpng-dev libpng-tools
#   libpthread-stubs0-dev libselinux1-dev libsepol1-dev libsm-dev libuuid1
#   libx11-6 libx11-dev libxau-dev libxcb-render0-dev libxcb-shm0-dev
#   libxcb1-dev libxdmcp-dev libxext-dev libxrender-dev uuid-dev
#   x11proto-core-dev x11proto-dev x11proto-xext-dev xorg-sgml-doctools
#   xtrans-dev
# Suggested packages:
#   libcairo2-doc freetype2-doc libgirepository1.0-dev libglib2.0-doc
#   libgdk-pixbuf2.0-bin | libgdk-pixbuf2.0-dev libxml2-utils libice-doc
#   libsm-doc libx11-doc libxcb-doc libxext-doc
# Recommended packages:
#   xdg-user-dirs uuid-runtime
# The following NEW packages will be installed:
#   libblkid-dev libcairo-script-interpreter2 libcairo2-dev libffi-dev
#   libfontconfig1-dev libfreetype-dev libfreetype6-dev libgif-dev
#   libglib2.0-dev libglib2.0-dev-bin libice-dev libjpeg-dev libjpeg-turbo8-dev
#   libjpeg8-dev liblzo2-2 libmount-dev libpcre16-3 libpcre2-16-0 libpcre2-32-0
#   libpcre2-dev libpcre2-posix2 libpcre3-dev libpcre32-3 libpcrecpp0v5
#   libpixman-1-dev libpng-dev libpng-tools libpthread-stubs0-dev
#   libselinux1-dev libsepol1-dev libsm-dev libx11-dev libxau-dev
#   libxcb-render0-dev libxcb-shm0-dev libxcb1-dev libxdmcp-dev libxext-dev
#   libxrender-dev uuid-dev x11proto-core-dev x11proto-dev x11proto-xext-dev
#   xorg-sgml-doctools xtrans-dev
# The following packages will be upgraded:
#   libblkid1 libfreetype6 libglib2.0-0 libglib2.0-bin libmount1 libuuid1
#   libx11-6
# 7 upgraded, 45 newly installed, 0 to remove and 168 not upgraded.
# Need to get 11.3 MB of archives.
# After this operation, 39.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libblkid1 amd64 2.34-0.1ubuntu9.6 [137 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmount1 amd64 2.34-0.1ubuntu9.6 [149 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libuuid1 amd64 2.34-0.1ubuntu9.6 [20.0 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-bin amd64 2.64.6-1~ubuntu20.04.6 [72.9 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-0 amd64 2.64.6-1~ubuntu20.04.6 [1289 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libx11-6 amd64 2:1.6.9-2ubuntu1.6 [577 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libfreetype6 amd64 2.10.1-2ubuntu0.3 [341 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 liblzo2-2 amd64 2.10-2 [50.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 libcairo-script-interpreter2 amd64 1.16.0-4ubuntu1 [54.2 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 libpng-dev amd64 1.6.37-2 [175 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libfreetype-dev amd64 2.10.1-2ubuntu0.3 [493 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libfreetype6-dev amd64 2.10.1-2ubuntu0.3 [9808 B]
# Get:13 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 uuid-dev amd64 2.34-0.1ubuntu9.6 [33.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontconfig1-dev amd64 2.13.1-2ubuntu3 [731 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/main amd64 xorg-sgml-doctools all 1:1.11-1 [12.9 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-dev all 2019.2-1ubuntu1 [594 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-core-dev all 2019.2-1ubuntu1 [2620 B]
# Get:18 http://archive.ubuntu.com/ubuntu focal/main amd64 libxau-dev amd64 1:1.0.9-0ubuntu1 [9552 B]
# Get:19 http://archive.ubuntu.com/ubuntu focal/main amd64 libxdmcp-dev amd64 1:1.1.3-0ubuntu1 [25.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 xtrans-dev all 1.4.0-1 [68.9 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal/main amd64 libpthread-stubs0-dev amd64 0.4-1 [5384 B]
# Get:22 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb1-dev amd64 1.14-2 [80.5 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libx11-dev amd64 2:1.6.9-2ubuntu1.6 [648 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal/main amd64 libxrender-dev amd64 1:0.9.10-1 [24.9 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/main amd64 x11proto-xext-dev all 2019.2-1ubuntu1 [2616 B]
# Get:26 http://archive.ubuntu.com/ubuntu focal/main amd64 libxext-dev amd64 2:1.3.4-0ubuntu1 [82.2 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal/main amd64 libice-dev amd64 2:1.0.10-0ubuntu1 [47.8 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal/main amd64 libsm-dev amd64 2:1.2.3-1 [17.0 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpixman-1-dev amd64 0.38.4-0ubuntu2.1 [243 kB]
# Get:30 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-render0-dev amd64 1.14-2 [18.4 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal/main amd64 libxcb-shm0-dev amd64 1.14-2 [6716 B]
# Get:32 http://archive.ubuntu.com/ubuntu focal/main amd64 libffi-dev amd64 3.3-4 [57.0 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-dev-bin amd64 2.64.6-1~ubuntu20.04.6 [109 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libblkid-dev amd64 2.34-0.1ubuntu9.6 [167 kB]
# Get:35 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libmount-dev amd64 2.34-0.1ubuntu9.6 [176 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpcre16-3 amd64 2:8.39-12ubuntu0.1 [150 kB]
# Get:37 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpcre32-3 amd64 2:8.39-12ubuntu0.1 [140 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpcrecpp0v5 amd64 2:8.39-12ubuntu0.1 [15.5 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpcre3-dev amd64 2:8.39-12ubuntu0.1 [540 kB]
# Get:40 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libsepol1-dev amd64 3.0-1ubuntu0.1 [325 kB]
# Get:41 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpcre2-16-0 amd64 10.34-7ubuntu0.1 [181 kB]
# Get:42 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpcre2-32-0 amd64 10.34-7ubuntu0.1 [170 kB]
# Get:43 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpcre2-posix2 amd64 10.34-7ubuntu0.1 [5988 B]
# Get:44 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libpcre2-dev amd64 10.34-7ubuntu0.1 [672 kB]
# Get:45 http://archive.ubuntu.com/ubuntu focal/main amd64 libselinux1-dev amd64 3.0-1build2 [151 kB]
# Get:46 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libglib2.0-dev amd64 2.64.6-1~ubuntu20.04.6 [1507 kB]
# Get:47 http://archive.ubuntu.com/ubuntu focal/main amd64 libcairo2-dev amd64 1.16.0-4ubuntu1 [627 kB]
# Get:48 http://archive.ubuntu.com/ubuntu focal/main amd64 libgif-dev amd64 5.1.9-1 [20.6 kB]
# Get:49 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libjpeg-turbo8-dev amd64 2.0.3-0ubuntu1.20.04.3 [238 kB]
# Get:50 http://archive.ubuntu.com/ubuntu focal/main amd64 libjpeg8-dev amd64 8c-2ubuntu8 [1552 B]
# Get:51 http://archive.ubuntu.com/ubuntu focal/main amd64 libjpeg-dev amd64 8c-2ubuntu8 [1546 B]
# Get:52 http://archive.ubuntu.com/ubuntu focal/main amd64 libpng-tools amd64 1.6.37-2 [26.1 kB]
# Fetched 11.3 MB in 0s (29.8 MB/s)
# Extracting templates from packages: 100%
# (Reading database ... 69943 files and directories currently installed.)
# Preparing to unpack .../libblkid1_2.34-0.1ubuntu9.6_amd64.deb ...
# Unpacking libblkid1:amd64 (2.34-0.1ubuntu9.6) over (2.34-0.1ubuntu9.3) ...
# Setting up libblkid1:amd64 (2.34-0.1ubuntu9.6) ...
# (Reading database ... 69943 files and directories currently installed.)
# Preparing to unpack .../libmount1_2.34-0.1ubuntu9.6_amd64.deb ...
# Unpacking libmount1:amd64 (2.34-0.1ubuntu9.6) over (2.34-0.1ubuntu9.3) ...
# Setting up libmount1:amd64 (2.34-0.1ubuntu9.6) ...
# (Reading database ... 69943 files and directories currently installed.)
# Preparing to unpack .../libuuid1_2.34-0.1ubuntu9.6_amd64.deb ...
# Unpacking libuuid1:amd64 (2.34-0.1ubuntu9.6) over (2.34-0.1ubuntu9.3) ...
# Setting up libuuid1:amd64 (2.34-0.1ubuntu9.6) ...
# (Reading database ... 69943 files and directories currently installed.)
# Preparing to unpack .../00-libglib2.0-bin_2.64.6-1~ubuntu20.04.6_amd64.deb ...
# Unpacking libglib2.0-bin (2.64.6-1~ubuntu20.04.6) over (2.64.6-1~ubuntu20.04.4) ...
# Preparing to unpack .../01-libglib2.0-0_2.64.6-1~ubuntu20.04.6_amd64.deb ...
# Unpacking libglib2.0-0:amd64 (2.64.6-1~ubuntu20.04.6) over (2.64.6-1~ubuntu20.04.4) ...
# Preparing to unpack .../02-libx11-6_2%3a1.6.9-2ubuntu1.6_amd64.deb ...
# Unpacking libx11-6:amd64 (2:1.6.9-2ubuntu1.6) over (2:1.6.9-2ubuntu1.2) ...
# Preparing to unpack .../03-libfreetype6_2.10.1-2ubuntu0.3_amd64.deb ...
# Unpacking libfreetype6:amd64 (2.10.1-2ubuntu0.3) over (2.10.1-2ubuntu0.2) ...
# Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../04-liblzo2-2_2.10-2_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../05-libcairo-script-interpreter2_1.16.0-4ubuntu1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.16.0-4ubuntu1) ...
# Selecting previously unselected package libpng-dev:amd64.
# Preparing to unpack .../06-libpng-dev_1.6.37-2_amd64.deb ...
# Unpacking libpng-dev:amd64 (1.6.37-2) ...
# Selecting previously unselected package libfreetype-dev:amd64.
# Preparing to unpack .../07-libfreetype-dev_2.10.1-2ubuntu0.3_amd64.deb ...
# Unpacking libfreetype-dev:amd64 (2.10.1-2ubuntu0.3) ...
# Selecting previously unselected package libfreetype6-dev:amd64.
# Preparing to unpack .../08-libfreetype6-dev_2.10.1-2ubuntu0.3_amd64.deb ...
# Unpacking libfreetype6-dev:amd64 (2.10.1-2ubuntu0.3) ...
# Selecting previously unselected package uuid-dev:amd64.
# Preparing to unpack .../09-uuid-dev_2.34-0.1ubuntu9.6_amd64.deb ...
# Unpacking uuid-dev:amd64 (2.34-0.1ubuntu9.6) ...
# Selecting previously unselected package libfontconfig1-dev:amd64.
# Preparing to unpack .../10-libfontconfig1-dev_2.13.1-2ubuntu3_amd64.deb ...
# Unpacking libfontconfig1-dev:amd64 (2.13.1-2ubuntu3) ...
# Selecting previously unselected package xorg-sgml-doctools.
# Preparing to unpack .../11-xorg-sgml-doctools_1%3a1.11-1_all.deb ...
# Unpacking xorg-sgml-doctools (1:1.11-1) ...
# Selecting previously unselected package x11proto-dev.
# Preparing to unpack .../12-x11proto-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package x11proto-core-dev.
# Preparing to unpack .../13-x11proto-core-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-core-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxau-dev:amd64.
# Preparing to unpack .../14-libxau-dev_1%3a1.0.9-0ubuntu1_amd64.deb ...
# Unpacking libxau-dev:amd64 (1:1.0.9-0ubuntu1) ...
# Selecting previously unselected package libxdmcp-dev:amd64.
# Preparing to unpack .../15-libxdmcp-dev_1%3a1.1.3-0ubuntu1_amd64.deb ...
# Unpacking libxdmcp-dev:amd64 (1:1.1.3-0ubuntu1) ...
# Selecting previously unselected package xtrans-dev.
# Preparing to unpack .../16-xtrans-dev_1.4.0-1_all.deb ...
# Unpacking xtrans-dev (1.4.0-1) ...
# Selecting previously unselected package libpthread-stubs0-dev:amd64.
# Preparing to unpack .../17-libpthread-stubs0-dev_0.4-1_amd64.deb ...
# Unpacking libpthread-stubs0-dev:amd64 (0.4-1) ...
# Selecting previously unselected package libxcb1-dev:amd64.
# Preparing to unpack .../18-libxcb1-dev_1.14-2_amd64.deb ...
# Unpacking libxcb1-dev:amd64 (1.14-2) ...
# Selecting previously unselected package libx11-dev:amd64.
# Preparing to unpack .../19-libx11-dev_2%3a1.6.9-2ubuntu1.6_amd64.deb ...
# Unpacking libx11-dev:amd64 (2:1.6.9-2ubuntu1.6) ...
# Selecting previously unselected package libxrender-dev:amd64.
# Preparing to unpack .../20-libxrender-dev_1%3a0.9.10-1_amd64.deb ...
# Unpacking libxrender-dev:amd64 (1:0.9.10-1) ...
# Selecting previously unselected package x11proto-xext-dev.
# Preparing to unpack .../21-x11proto-xext-dev_2019.2-1ubuntu1_all.deb ...
# Unpacking x11proto-xext-dev (2019.2-1ubuntu1) ...
# Selecting previously unselected package libxext-dev:amd64.
# Preparing to unpack .../22-libxext-dev_2%3a1.3.4-0ubuntu1_amd64.deb ...
# Unpacking libxext-dev:amd64 (2:1.3.4-0ubuntu1) ...
# Selecting previously unselected package libice-dev:amd64.
# Preparing to unpack .../23-libice-dev_2%3a1.0.10-0ubuntu1_amd64.deb ...
# Unpacking libice-dev:amd64 (2:1.0.10-0ubuntu1) ...
# Selecting previously unselected package libsm-dev:amd64.
# Preparing to unpack .../24-libsm-dev_2%3a1.2.3-1_amd64.deb ...
# Unpacking libsm-dev:amd64 (2:1.2.3-1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../25-libpixman-1-dev_0.38.4-0ubuntu2.1_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.38.4-0ubuntu2.1) ...
# Selecting previously unselected package libxcb-render0-dev:amd64.
# Preparing to unpack .../26-libxcb-render0-dev_1.14-2_amd64.deb ...
# Unpacking libxcb-render0-dev:amd64 (1.14-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../27-libxcb-shm0-dev_1.14-2_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.14-2) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../28-libffi-dev_3.3-4_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.3-4) ...
# Selecting previously unselected package libglib2.0-dev-bin.
# Preparing to unpack .../29-libglib2.0-dev-bin_2.64.6-1~ubuntu20.04.6_amd64.deb ...
# Unpacking libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.6) ...
# Selecting previously unselected package libblkid-dev:amd64.
# Preparing to unpack .../30-libblkid-dev_2.34-0.1ubuntu9.6_amd64.deb ...
# Unpacking libblkid-dev:amd64 (2.34-0.1ubuntu9.6) ...
# Selecting previously unselected package libmount-dev:amd64.
# Preparing to unpack .../31-libmount-dev_2.34-0.1ubuntu9.6_amd64.deb ...
# Unpacking libmount-dev:amd64 (2.34-0.1ubuntu9.6) ...
# Selecting previously unselected package libpcre16-3:amd64.
# Preparing to unpack .../32-libpcre16-3_2%3a8.39-12ubuntu0.1_amd64.deb ...
# Unpacking libpcre16-3:amd64 (2:8.39-12ubuntu0.1) ...
# Selecting previously unselected package libpcre32-3:amd64.
# Preparing to unpack .../33-libpcre32-3_2%3a8.39-12ubuntu0.1_amd64.deb ...
# Unpacking libpcre32-3:amd64 (2:8.39-12ubuntu0.1) ...
# Selecting previously unselected package libpcrecpp0v5:amd64.
# Preparing to unpack .../34-libpcrecpp0v5_2%3a8.39-12ubuntu0.1_amd64.deb ...
# Unpacking libpcrecpp0v5:amd64 (2:8.39-12ubuntu0.1) ...
# Selecting previously unselected package libpcre3-dev:amd64.
# Preparing to unpack .../35-libpcre3-dev_2%3a8.39-12ubuntu0.1_amd64.deb ...
# Unpacking libpcre3-dev:amd64 (2:8.39-12ubuntu0.1) ...
# Selecting previously unselected package libsepol1-dev:amd64.
# Preparing to unpack .../36-libsepol1-dev_3.0-1ubuntu0.1_amd64.deb ...
# Unpacking libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# Selecting previously unselected package libpcre2-16-0:amd64.
# Preparing to unpack .../37-libpcre2-16-0_10.34-7ubuntu0.1_amd64.deb ...
# Unpacking libpcre2-16-0:amd64 (10.34-7ubuntu0.1) ...
# Selecting previously unselected package libpcre2-32-0:amd64.
# Preparing to unpack .../38-libpcre2-32-0_10.34-7ubuntu0.1_amd64.deb ...
# Unpacking libpcre2-32-0:amd64 (10.34-7ubuntu0.1) ...
# Selecting previously unselected package libpcre2-posix2:amd64.
# Preparing to unpack .../39-libpcre2-posix2_10.34-7ubuntu0.1_amd64.deb ...
# Unpacking libpcre2-posix2:amd64 (10.34-7ubuntu0.1) ...
# Selecting previously unselected package libpcre2-dev:amd64.
# Preparing to unpack .../40-libpcre2-dev_10.34-7ubuntu0.1_amd64.deb ...
# Unpacking libpcre2-dev:amd64 (10.34-7ubuntu0.1) ...
# Selecting previously unselected package libselinux1-dev:amd64.
# Preparing to unpack .../41-libselinux1-dev_3.0-1build2_amd64.deb ...
# Unpacking libselinux1-dev:amd64 (3.0-1build2) ...
# Selecting previously unselected package libglib2.0-dev:amd64.
# Preparing to unpack .../42-libglib2.0-dev_2.64.6-1~ubuntu20.04.6_amd64.deb ...
# Unpacking libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.6) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../43-libcairo2-dev_1.16.0-4ubuntu1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.16.0-4ubuntu1) ...
# Selecting previously unselected package libgif-dev.
# Preparing to unpack .../44-libgif-dev_5.1.9-1_amd64.deb ...
# Unpacking libgif-dev (5.1.9-1) ...
# Selecting previously unselected package libjpeg-turbo8-dev:amd64.
# Preparing to unpack .../45-libjpeg-turbo8-dev_2.0.3-0ubuntu1.20.04.3_amd64.deb ...
# Unpacking libjpeg-turbo8-dev:amd64 (2.0.3-0ubuntu1.20.04.3) ...
# Selecting previously unselected package libjpeg8-dev:amd64.
# Preparing to unpack .../46-libjpeg8-dev_8c-2ubuntu8_amd64.deb ...
# Unpacking libjpeg8-dev:amd64 (8c-2ubuntu8) ...
# Selecting previously unselected package libjpeg-dev:amd64.
# Preparing to unpack .../47-libjpeg-dev_8c-2ubuntu8_amd64.deb ...
# Unpacking libjpeg-dev:amd64 (8c-2ubuntu8) ...
# Selecting previously unselected package libpng-tools.
# Preparing to unpack .../48-libpng-tools_1.6.37-2_amd64.deb ...
# Unpacking libpng-tools (1.6.37-2) ...
# Setting up libpcrecpp0v5:amd64 (2:8.39-12ubuntu0.1) ...
# Setting up libjpeg-turbo8-dev:amd64 (2.0.3-0ubuntu1.20.04.3) ...
# Setting up libpixman-1-dev:amd64 (0.38.4-0ubuntu2.1) ...
# Setting up libpcre16-3:amd64 (2:8.39-12ubuntu0.1) ...
# Setting up libpng-tools (1.6.37-2) ...
# Setting up libglib2.0-0:amd64 (2.64.6-1~ubuntu20.04.6) ...
# Setting up libpng-dev:amd64 (1.6.37-2) ...
# Setting up libsepol1-dev:amd64 (3.0-1ubuntu0.1) ...
# Setting up libglib2.0-bin (2.64.6-1~ubuntu20.04.6) ...
# Setting up liblzo2-2:amd64 (2.10-2) ...
# Setting up libffi-dev:amd64 (3.3-4) ...
# Setting up libpthread-stubs0-dev:amd64 (0.4-1) ...
# Setting up libpcre2-16-0:amd64 (10.34-7ubuntu0.1) ...
# Setting up xtrans-dev (1.4.0-1) ...
# Setting up libpcre2-32-0:amd64 (10.34-7ubuntu0.1) ...
# Setting up libfreetype6:amd64 (2.10.1-2ubuntu0.3) ...
# Setting up uuid-dev:amd64 (2.34-0.1ubuntu9.6) ...
# Setting up libpcre32-3:amd64 (2:8.39-12ubuntu0.1) ...
# Setting up libpcre2-posix2:amd64 (10.34-7ubuntu0.1) ...
# Setting up libgif-dev (5.1.9-1) ...
# Setting up libx11-6:amd64 (2:1.6.9-2ubuntu1.6) ...
# Setting up xorg-sgml-doctools (1:1.11-1) ...
# Setting up libjpeg8-dev:amd64 (8c-2ubuntu8) ...
# Setting up x11proto-dev (2019.2-1ubuntu1) ...
# Setting up libcairo-script-interpreter2:amd64 (1.16.0-4ubuntu1) ...
# Setting up libglib2.0-dev-bin (2.64.6-1~ubuntu20.04.6) ...
# Setting up libblkid-dev:amd64 (2.34-0.1ubuntu9.6) ...
# Setting up libxau-dev:amd64 (1:1.0.9-0ubuntu1) ...
# Setting up libpcre2-dev:amd64 (10.34-7ubuntu0.1) ...
# Setting up libice-dev:amd64 (2:1.0.10-0ubuntu1) ...
# Setting up libsm-dev:amd64 (2:1.2.3-1) ...
# Setting up libselinux1-dev:amd64 (3.0-1build2) ...
# Setting up libpcre3-dev:amd64 (2:8.39-12ubuntu0.1) ...
# Setting up libjpeg-dev:amd64 (8c-2ubuntu8) ...
# Setting up libfreetype-dev:amd64 (2.10.1-2ubuntu0.3) ...
# Setting up libxdmcp-dev:amd64 (1:1.1.3-0ubuntu1) ...
# Setting up x11proto-core-dev (2019.2-1ubuntu1) ...
# Setting up x11proto-xext-dev (2019.2-1ubuntu1) ...
# Setting up libmount-dev:amd64 (2.34-0.1ubuntu9.6) ...
# Setting up libxcb1-dev:amd64 (1.14-2) ...
# Setting up libx11-dev:amd64 (2:1.6.9-2ubuntu1.6) ...
# Setting up libfreetype6-dev:amd64 (2.10.1-2ubuntu0.3) ...
# Setting up libxcb-shm0-dev:amd64 (1.14-2) ...
# Setting up libglib2.0-dev:amd64 (2.64.6-1~ubuntu20.04.6) ...
# Setting up libxcb-render0-dev:amd64 (1.14-2) ...
# Setting up libxext-dev:amd64 (2:1.3.4-0ubuntu1) ...
# Setting up libxrender-dev:amd64 (1:0.9.10-1) ...
# Setting up libfontconfig1-dev:amd64 (2.13.1-2ubuntu3) ...
# Setting up libcairo2-dev:amd64 (1.16.0-4ubuntu1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for install-info (6.7.0.dfsg.2-5) ...

# %%
REQUIREMENTS_CONTENT="""
absl-py==1.4.0
agate==1.6.0
agate-dbf==0.2.0
agate-excel==0.2.3
agate-sql==0.5.2
aiohttp==3.8.3
aiosignal==1.3.1
anyio==3.6.2
argon2-cffi==21.3.0
argon2-cffi-bindings==21.2.0
asttokens==2.2.1
astunparse==1.6.3
async-timeout==4.0.2
attrs>=18.2.0
awscli==1.25.91
Babel==2.11.0
backcall==0.2.0
beautifulsoup4==4.11.1
bleach==6.0.0
blis==0.7.9
boto3==1.24.90
botocore==1.27.90
cached-property==1.5.2
cachetools==5.3.0
catalogue==2.0.8
certifi==2019.11.28
cffi==1.15.1
chardet==3.0.4
charset-normalizer==2.1.1
chex==0.1.5
click==8.1.3
click-completion==0.5.2
click-didyoumean==0.3.0
click-help-colors==0.9.1
cloudpickle==2.2.0
colorama==0.4.3
comm==0.1.2
confection>=0.0.4
contourpy==1.0.7
csvkit==1.0.2
cycler==0.11.0
cymem==2.0.7
Cython==0.29.32
datasets==2.4.0
dbfread==2.0.7
dbus-python==1.2.16
debugpy==1.6.6
decorator==5.1.1
defusedxml==0.7.1
dill==0.3.5.1
dm-tree==0.1.8
docker-pycreds==0.4.0
docutils==0.16
entrypoints==0.4
et-xmlfile==1.0.1
etils==1.0.0
exceptiongroup==1.1.0
executing==1.2.0
fastjsonschema==2.16.2
filelock==3.9.0
flatbuffers==1.12
flax==0.6.3
fonttools==4.38.0
frozenlist==1.3.3
fsspec==2023.1.0
future==0.18.2
gast==0.4.0
gdown==4.5.1
gitdb==4.0.10
GitPython==3.1.30
google-auth==2.16.0
google-auth-oauthlib==0.4.6
google-pasta==0.2.0
gql==3.0.0a6
gradient==2.0.6
gradient-utils==0.5.0
graphql-core==3.1.7
greenlet==2.0.1
grpcio==1.51.1
h5py==3.8.0
halo==0.0.31
huggingface-hub==0.12.0
idna==2.8
imageio==2.25.0
importlib-metadata==6.0.0
importlib-resources==5.10.2
iniconfig==2.0.0
ipykernel==6.16.0
ipython==8.5.0
ipython-genutils==0.2.0
ipywidgets==8.0.2
isodate==0.6.0
jax==0.4.1
jaxlib==0.4.1+cuda11.cudnn82
jdcal==1.0
jedi==0.18.2
Jinja2==3.1.2
jmespath==1.0.1
joblib==1.2.0
json5==0.9.11
jsonify==0.5
jsonschema==4.17.3
jupyter-client==7.3.4
jupyter-contrib-core==0.4.2
jupyter-contrib-nbextensions==0.7.0
jupyter-highlight-selected-word==0.2.0
jupyter-nbextensions-configurator==0.6.1
jupyter-server==1.23.5
jupyter-server-mathjax==0.2.6
jupyter_core==5.1.5
jupyterlab==3.4.6
jupyterlab-git==0.41.0
jupyterlab-pygments==0.2.2
jupyterlab-snippets==0.4.1
jupyterlab-widgets==3.0.5
jupyterlab_server==2.19.0
keras==2.9.0
Keras-Preprocessing==1.1.2
kiwisolver==1.4.4
langcodes==3.3.0
leather==0.3.3
libclang==15.0.6.1
log-symbols==0.0.14
lxml==4.5.0
Markdown==3.4.1
markdown-it-py==2.1.0
MarkupSafe==2.1.2
marshmallow==2.21.0
matplotlib==3.6.1
matplotlib-inline==0.1.6
mdurl==0.1.2
mistune==2.0.4
msgpack==1.0.4
multidict==6.0.4
multiprocess==0.70.13
murmurhash==1.0.9
nbclassic==0.4.8
nbclient==0.7.2
nbconvert==7.2.9
nbdime==3.1.1
nbformat==5.7.3
nest-asyncio==1.5.6
networkx==3.0
nltk==3.7
notebook==6.5.2
notebook_shim==0.2.2
numpy==1.23.4
oauthlib==3.2.2
opencv-python==4.6.0.66
openpyxl==3.0.3
opt-einsum==3.3.0
optax==0.1.4
orbax==0.1.0
packaging==23.0
pandas==1.5.0
pandocfilters==1.5.0
parsedatetime==2.4
parso==0.8.3
pathtools==0.1.2
pathy==0.10.1
pexpect==4.8.0
pickleshare==0.7.5
Pillow==9.2.0
platformdirs==2.6.2
pluggy==1.0.0
preshed==3.0.8
progressbar2==4.2.0
prometheus-client==0.9.0
promise==2.3
prompt-toolkit==3.0.36
protobuf==3.19.6
psutil==5.9.4
ptyprocess==0.7.0
pure-eval==0.2.2
pyarrow==10.0.1
pyasn1==0.4.8
pyasn1-modules==0.2.8
pycparser==2.21
pydantic==1.9.2
Pygments==2.14.0
PyGObject==3.36.0
pymongo==3.13.0
pyparsing==3.0.9
pyrsistent==0.19.3
PySocks==1.7.1
python-apt==2.0.1
python-dateutil==2.8.2
python-distutils-extra==2.39
python-slugify==4.0.0
python-utils==3.4.5
pytimeparse==1.1.5
pytz==2022.7.1
PyWavelets==1.4.1
PyYAML==5.4.1
pyzmq==25.0.0
regex==2022.10.31
requests==2.28.2
requests-oauthlib==1.3.1
requests-toolbelt==0.10.1
requests-unixsocket==0.2.0
responses==0.18.0
rich==13.2.0
rsa==4.7.2
s3transfer==0.6.0
scikit-image==0.19.3
scikit-learn==1.1.2
scipy==1.9.2
seaborn==0.12.0
Send2Trash==1.8.0
sentence-transformers==2.2.2
sentencepiece==0.1.97
sentry-sdk==1.14.0
setproctitle==1.3.2
shellingham==1.5.0.post1
shortuuid==1.0.11
six==1.14.0
smart-open==6.3.0
smmap==5.0.0
sniffio==1.3.0
soupsieve==2.3.2.post1
spacy>=3.4.1
spacy-llm==0.7.1
spacy-legacy==3.0.12
spacy-loggers==1.0.4
spinners==0.0.24
SQLAlchemy==1.4.41
srsly==2.4.5
stack-data==0.6.2
tabulate==0.9.0
tensorboard==2.9.1
tensorboard-data-server==0.6.1
tensorboard-plugin-wit==1.8.1
tensorflow==2.9.2
tensorflow-estimator==2.9.0
tensorflow-io-gcs-filesystem==0.30.0
tensorstore==0.1.30
termcolor==2.2.0
terminado==0.17.1
terminaltables==3.1.10
thinc==8.1.7
threadpoolctl==3.1.0
tifffile==2023.1.23.1
tinycss2==1.2.1
tokenizers==0.12.1
tomli==2.0.1
toolz==0.12.0
torch==1.12.1+cu116
torchaudio==0.12.1+cu116
torchvision==0.13.1+cu116
tornado==6.1
tqdm==4.64.1
traitlets==5.8.1
transformers==4.40.1
typer==0.4.2
typing_extensions==4.4.0
Unidecode==1.1.1
urllib3==1.26.14
wandb==0.13.4
wasabi==0.10.1
wcwidth==0.2.6
webencodings==0.5.1
websocket-client==0.57.0
Werkzeug==2.2.2
widgetsnbextension==4.0.5
wrapt==1.14.1
xgboost==1.6.2
xlrd==1.1.0
xxhash==3.2.0
yarl==1.8.2
zipp==3.11.0
"""

with open('requirements.txt', 'w') as f:
    f.write(REQUIREMENTS_CONTENT)

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: absl-py==1.4.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: agate==1.6.0 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: agate-dbf==0.2.0 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: agate-excel==0.2.3 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 5)) (0.2.3)
# Requirement already satisfied: agate-sql==0.5.2 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 6)) (0.5.2)
# Requirement already satisfied: aiohttp==3.8.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 7)) (3.8.3)
# Requirement already satisfied: aiosignal==1.3.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: anyio==3.6.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 9)) (3.6.2)
# Requirement already satisfied: argon2-cffi==21.3.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 10)) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 11)) (21.2.0)
# Requirement already satisfied: asttokens==2.2.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 12)) (2.2.1)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 13)) (1.6.3)
# Requirement already satisfied: async-timeout==4.0.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 14)) (4.0.2)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 15)) (18.2.0)
# Requirement already satisfied: awscli==1.25.91 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 16)) (1.25.91)
# Requirement already satisfied: Babel==2.11.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 17)) (2.11.0)
# Requirement already satisfied: backcall==0.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 18)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.11.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 19)) (4.11.1)
# Requirement already satisfied: bleach==6.0.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 20)) (6.0.0)
# Requirement already satisfied: blis==0.7.9 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 21)) (0.7.9)
# Requirement already satisfied: boto3==1.24.90 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 22)) (1.24.90)
# Requirement already satisfied: botocore==1.27.90 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 23)) (1.27.90)
# Requirement already satisfied: cached-property==1.5.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 24)) (1.5.2)
# Requirement already satisfied: cachetools==5.3.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 25)) (5.3.0)
# Requirement already satisfied: catalogue==2.0.8 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 26)) (2.0.8)
# Requirement already satisfied: certifi==2019.11.28 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 27)) (2019.11.28)
# Requirement already satisfied: cffi==1.15.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 28)) (1.15.1)
# Requirement already satisfied: chardet==3.0.4 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 29)) (3.0.4)
# Requirement already satisfied: charset-normalizer==2.1.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 30)) (2.1.1)
# Requirement already satisfied: chex==0.1.5 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 31)) (0.1.5)
# Requirement already satisfied: click==8.1.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 32)) (8.1.3)
# Requirement already satisfied: click-completion==0.5.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 33)) (0.5.2)
# Requirement already satisfied: click-didyoumean==0.3.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 34)) (0.3.0)
# Requirement already satisfied: click-help-colors==0.9.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 35)) (0.9.1)
# Requirement already satisfied: cloudpickle==2.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 36)) (2.2.0)
# Requirement already satisfied: colorama==0.4.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 37)) (0.4.3)
# Requirement already satisfied: comm==0.1.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 38)) (0.1.2)
# Requirement already satisfied: confection>=0.0.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 39)) (0.1.4)
# Requirement already satisfied: contourpy==1.0.7 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 40)) (1.0.7)
# Requirement already satisfied: csvkit==1.0.2 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 41)) (1.0.2)
# Requirement already satisfied: cycler==0.11.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 42)) (0.11.0)
# Requirement already satisfied: cymem==2.0.7 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 43)) (2.0.7)
# Requirement already satisfied: Cython==0.29.32 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 44)) (0.29.32)
# Requirement already satisfied: datasets==2.4.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 45)) (2.4.0)
# Requirement already satisfied: dbfread==2.0.7 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 46)) (2.0.7)
# Requirement already satisfied: dbus-python==1.2.16 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 47)) (1.2.16)
# Requirement already satisfied: debugpy==1.6.6 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 48)) (1.6.6)
# Requirement already satisfied: decorator==5.1.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 49)) (5.1.1)
# Requirement already satisfied: defusedxml==0.7.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 50)) (0.7.1)
# Requirement already satisfied: dill==0.3.5.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 51)) (0.3.5.1)
# Requirement already satisfied: dm-tree==0.1.8 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 52)) (0.1.8)
# Requirement already satisfied: docker-pycreds==0.4.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 53)) (0.4.0)
# Requirement already satisfied: docutils==0.16 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 54)) (0.16)
# Requirement already satisfied: entrypoints==0.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 55)) (0.4)
# Requirement already satisfied: et-xmlfile==1.0.1 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 56)) (1.0.1)
# Requirement already satisfied: etils==1.0.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 57)) (1.0.0)
# Requirement already satisfied: exceptiongroup==1.1.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 58)) (1.1.0)
# Requirement already satisfied: executing==1.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 59)) (1.2.0)
# Requirement already satisfied: fastjsonschema==2.16.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 60)) (2.16.2)
# Requirement already satisfied: filelock==3.9.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 61)) (3.9.0)
# Requirement already satisfied: flatbuffers==1.12 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 62)) (1.12)
# Requirement already satisfied: flax==0.6.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 63)) (0.6.3)
# Requirement already satisfied: fonttools==4.38.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 64)) (4.38.0)
# Requirement already satisfied: frozenlist==1.3.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 65)) (1.3.3)
# Requirement already satisfied: fsspec==2023.1.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 66)) (2023.1.0)
# Requirement already satisfied: future==0.18.2 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 67)) (0.18.2)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 68)) (0.4.0)
# Requirement already satisfied: gdown==4.5.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 69)) (4.5.1)
# Requirement already satisfied: gitdb==4.0.10 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 70)) (4.0.10)
# Requirement already satisfied: GitPython==3.1.30 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 71)) (3.1.30)
# Requirement already satisfied: google-auth==2.16.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 72)) (2.16.0)
# Requirement already satisfied: google-auth-oauthlib==0.4.6 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 73)) (0.4.6)
# Requirement already satisfied: google-pasta==0.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 74)) (0.2.0)
# Requirement already satisfied: gql==3.0.0a6 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 75)) (3.0.0a6)
# Requirement already satisfied: gradient==2.0.6 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 76)) (2.0.6)
# Requirement already satisfied: gradient-utils==0.5.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 77)) (0.5.0)
# Requirement already satisfied: graphql-core==3.1.7 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 78)) (3.1.7)
# Requirement already satisfied: greenlet==2.0.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 79)) (2.0.1)
# Requirement already satisfied: grpcio==1.51.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 80)) (1.51.1)
# Requirement already satisfied: h5py==3.8.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 81)) (3.8.0)
# Requirement already satisfied: halo==0.0.31 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 82)) (0.0.31)
# Requirement already satisfied: huggingface-hub==0.12.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 83)) (0.12.0)
# Requirement already satisfied: idna==2.8 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 84)) (2.8)
# Requirement already satisfied: imageio==2.25.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 85)) (2.25.0)
# Requirement already satisfied: importlib-metadata==6.0.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 86)) (6.0.0)
# Requirement already satisfied: importlib-resources==5.10.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 87)) (5.10.2)
# Requirement already satisfied: iniconfig==2.0.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 88)) (2.0.0)
# Requirement already satisfied: ipykernel==6.16.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 89)) (6.16.0)
# Requirement already satisfied: ipython==8.5.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 90)) (8.5.0)
# Requirement already satisfied: ipython-genutils==0.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 91)) (0.2.0)
# Requirement already satisfied: ipywidgets==8.0.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 92)) (8.0.2)
# Requirement already satisfied: isodate==0.6.0 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 93)) (0.6.0)
# Requirement already satisfied: jax==0.4.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 94)) (0.4.1)
# Requirement already satisfied: jaxlib==0.4.1+cuda11.cudnn82 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 95)) (0.4.1+cuda11.cudnn82)
# Requirement already satisfied: jdcal==1.0 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 96)) (1.0)
# Requirement already satisfied: jedi==0.18.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 97)) (0.18.2)
# Requirement already satisfied: Jinja2==3.1.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 98)) (3.1.2)
# Requirement already satisfied: jmespath==1.0.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 99)) (1.0.1)
# Requirement already satisfied: joblib==1.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 100)) (1.2.0)
# Requirement already satisfied: json5==0.9.11 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 101)) (0.9.11)
# Requirement already satisfied: jsonify==0.5 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 102)) (0.5)
# Requirement already satisfied: jsonschema==4.17.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 103)) (4.17.3)
# Requirement already satisfied: jupyter-client==7.3.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 104)) (7.3.4)
# Requirement already satisfied: jupyter-contrib-core==0.4.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 105)) (0.4.2)
# Requirement already satisfied: jupyter-contrib-nbextensions==0.7.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 106)) (0.7.0)
# Requirement already satisfied: jupyter-highlight-selected-word==0.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 107)) (0.2.0)
# Requirement already satisfied: jupyter-nbextensions-configurator==0.6.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 108)) (0.6.1)
# Requirement already satisfied: jupyter-server==1.23.5 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 109)) (1.23.5)
# Requirement already satisfied: jupyter-server-mathjax==0.2.6 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 110)) (0.2.6)
# Requirement already satisfied: jupyter_core==5.1.5 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 111)) (5.1.5)
# Requirement already satisfied: jupyterlab==3.4.6 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 112)) (3.4.6)
# Requirement already satisfied: jupyterlab-git==0.41.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 113)) (0.41.0)
# Requirement already satisfied: jupyterlab-pygments==0.2.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 114)) (0.2.2)
# Requirement already satisfied: jupyterlab-snippets==0.4.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 115)) (0.4.1)
# Requirement already satisfied: jupyterlab-widgets==3.0.5 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 116)) (3.0.5)
# Requirement already satisfied: jupyterlab_server==2.19.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 117)) (2.19.0)
# Requirement already satisfied: keras==2.9.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 118)) (2.9.0)
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 119)) (1.1.2)
# Requirement already satisfied: kiwisolver==1.4.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 120)) (1.4.4)
# Requirement already satisfied: langcodes==3.3.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 121)) (3.3.0)
# Requirement already satisfied: leather==0.3.3 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 122)) (0.3.3)
# Requirement already satisfied: libclang==15.0.6.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 123)) (15.0.6.1)
# Requirement already satisfied: log-symbols==0.0.14 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 124)) (0.0.14)
# Requirement already satisfied: lxml==4.5.0 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 125)) (4.5.0)
# Requirement already satisfied: Markdown==3.4.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 126)) (3.4.1)
# Requirement already satisfied: markdown-it-py==2.1.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 127)) (2.1.0)
# Requirement already satisfied: MarkupSafe==2.1.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 128)) (2.1.2)
# Requirement already satisfied: marshmallow==2.21.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 129)) (2.21.0)
# Requirement already satisfied: matplotlib==3.6.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 130)) (3.6.1)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 131)) (0.1.6)
# Requirement already satisfied: mdurl==0.1.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 132)) (0.1.2)
# Requirement already satisfied: mistune==2.0.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 133)) (2.0.4)
# Requirement already satisfied: msgpack==1.0.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 134)) (1.0.4)
# Requirement already satisfied: multidict==6.0.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 135)) (6.0.4)
# Requirement already satisfied: multiprocess==0.70.13 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 136)) (0.70.13)
# Requirement already satisfied: murmurhash==1.0.9 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 137)) (1.0.9)
# Requirement already satisfied: nbclassic==0.4.8 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 138)) (0.4.8)
# Requirement already satisfied: nbclient==0.7.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 139)) (0.7.2)
# Requirement already satisfied: nbconvert==7.2.9 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 140)) (7.2.9)
# Requirement already satisfied: nbdime==3.1.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 141)) (3.1.1)
# Requirement already satisfied: nbformat==5.7.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 142)) (5.7.3)
# Requirement already satisfied: nest-asyncio==1.5.6 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 143)) (1.5.6)
# Requirement already satisfied: networkx==3.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 144)) (3.0)
# Requirement already satisfied: nltk==3.7 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 145)) (3.7)
# Requirement already satisfied: notebook==6.5.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 146)) (6.5.2)
# Requirement already satisfied: notebook_shim==0.2.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 147)) (0.2.2)
# Requirement already satisfied: numpy==1.23.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 148)) (1.23.4)
# Requirement already satisfied: oauthlib==3.2.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 149)) (3.2.2)
# Requirement already satisfied: opencv-python==4.6.0.66 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 150)) (4.6.0.66)
# Requirement already satisfied: openpyxl==3.0.3 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 151)) (3.0.3)
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 152)) (3.3.0)
# Requirement already satisfied: optax==0.1.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 153)) (0.1.4)
# Requirement already satisfied: orbax==0.1.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 154)) (0.1.0)
# Requirement already satisfied: packaging==23.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 155)) (23.0)
# Requirement already satisfied: pandas==1.5.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 156)) (1.5.0)
# Requirement already satisfied: pandocfilters==1.5.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 157)) (1.5.0)
# Requirement already satisfied: parsedatetime==2.4 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 158)) (2.4)
# Requirement already satisfied: parso==0.8.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 159)) (0.8.3)
# Requirement already satisfied: pathtools==0.1.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 160)) (0.1.2)
# Requirement already satisfied: pathy==0.10.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 161)) (0.10.1)
# Requirement already satisfied: pexpect==4.8.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 162)) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 163)) (0.7.5)
# Requirement already satisfied: Pillow==9.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 164)) (9.2.0)
# Requirement already satisfied: platformdirs==2.6.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 165)) (2.6.2)
# Requirement already satisfied: pluggy==1.0.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 166)) (1.0.0)
# Requirement already satisfied: preshed==3.0.8 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 167)) (3.0.8)
# Requirement already satisfied: progressbar2==4.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 168)) (4.2.0)
# Requirement already satisfied: prometheus-client==0.9.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 169)) (0.9.0)
# Requirement already satisfied: promise==2.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 170)) (2.3)
# Requirement already satisfied: prompt-toolkit==3.0.36 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 171)) (3.0.36)
# Requirement already satisfied: protobuf==3.19.6 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 172)) (3.19.6)
# Requirement already satisfied: psutil==5.9.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 173)) (5.9.4)
# Requirement already satisfied: ptyprocess==0.7.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 174)) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 175)) (0.2.2)
# Requirement already satisfied: pyarrow==10.0.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 176)) (10.0.1)
# Requirement already satisfied: pyasn1==0.4.8 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 177)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 178)) (0.2.8)
# Requirement already satisfied: pycparser==2.21 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 179)) (2.21)
# Requirement already satisfied: pydantic==1.9.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 180)) (1.9.2)
# Requirement already satisfied: Pygments==2.14.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 181)) (2.14.0)
# Requirement already satisfied: PyGObject==3.36.0 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 182)) (3.36.0)
# Requirement already satisfied: pymongo==3.13.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 183)) (3.13.0)
# Requirement already satisfied: pyparsing==3.0.9 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 184)) (3.0.9)
# Requirement already satisfied: pyrsistent==0.19.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 185)) (0.19.3)
# Requirement already satisfied: PySocks==1.7.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 186)) (1.7.1)
# Requirement already satisfied: python-apt==2.0.1 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 187)) (2.0.1)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 188)) (2.8.2)
# Requirement already satisfied: python-distutils-extra==2.39 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 189)) (2.39)
# Requirement already satisfied: python-slugify==4.0.0 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 190)) (4.0.0)
# Requirement already satisfied: python-utils==3.4.5 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 191)) (3.4.5)
# Requirement already satisfied: pytimeparse==1.1.5 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 192)) (1.1.5)
# Requirement already satisfied: pytz==2022.7.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 193)) (2022.7.1)
# Requirement already satisfied: PyWavelets==1.4.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 194)) (1.4.1)
# Requirement already satisfied: PyYAML==5.4.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 195)) (5.4.1)
# Requirement already satisfied: pyzmq==25.0.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 196)) (25.0.0)
# Requirement already satisfied: regex==2022.10.31 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 197)) (2022.10.31)
# Requirement already satisfied: requests==2.28.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 198)) (2.28.2)
# Requirement already satisfied: requests-oauthlib==1.3.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 199)) (1.3.1)
# Requirement already satisfied: requests-toolbelt==0.10.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 200)) (0.10.1)
# Requirement already satisfied: requests-unixsocket==0.2.0 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 201)) (0.2.0)
# Requirement already satisfied: responses==0.18.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 202)) (0.18.0)
# Requirement already satisfied: rich==13.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 203)) (13.2.0)
# Requirement already satisfied: rsa==4.7.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 204)) (4.7.2)
# Requirement already satisfied: s3transfer==0.6.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 205)) (0.6.0)
# Requirement already satisfied: scikit-image==0.19.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 206)) (0.19.3)
# Requirement already satisfied: scikit-learn==1.1.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 207)) (1.1.2)
# Requirement already satisfied: scipy==1.9.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 208)) (1.9.2)
# Requirement already satisfied: seaborn==0.12.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 209)) (0.12.0)
# Requirement already satisfied: Send2Trash==1.8.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 210)) (1.8.0)
# Requirement already satisfied: sentence-transformers==2.2.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 211)) (2.2.2)
# Requirement already satisfied: sentencepiece==0.1.97 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 212)) (0.1.97)
# Requirement already satisfied: sentry-sdk==1.14.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 213)) (1.14.0)
# Requirement already satisfied: setproctitle==1.3.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 214)) (1.3.2)
# Requirement already satisfied: shellingham==1.5.0.post1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 215)) (1.5.0.post1)
# Requirement already satisfied: shortuuid==1.0.11 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 216)) (1.0.11)
# Requirement already satisfied: six==1.14.0 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 217)) (1.14.0)
# Requirement already satisfied: smart-open==6.3.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 218)) (6.3.0)
# Requirement already satisfied: smmap==5.0.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 219)) (5.0.0)
# Requirement already satisfied: sniffio==1.3.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 220)) (1.3.0)
# Requirement already satisfied: soupsieve==2.3.2.post1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 221)) (2.3.2.post1)
# Requirement already satisfied: spacy>=3.4.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 222)) (3.5.0)
# Requirement already satisfied: spacy-llm==0.7.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 223)) (0.7.1)
# Requirement already satisfied: spacy-legacy==3.0.12 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 224)) (3.0.12)
# Requirement already satisfied: spacy-loggers==1.0.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 225)) (1.0.4)
# Requirement already satisfied: spinners==0.0.24 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 226)) (0.0.24)
# Requirement already satisfied: SQLAlchemy==1.4.41 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 227)) (1.4.41)
# Requirement already satisfied: srsly==2.4.5 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 228)) (2.4.5)
# Requirement already satisfied: stack-data==0.6.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 229)) (0.6.2)
# Requirement already satisfied: tabulate==0.9.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 230)) (0.9.0)
# Requirement already satisfied: tensorboard==2.9.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 231)) (2.9.1)
# Requirement already satisfied: tensorboard-data-server==0.6.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 232)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit==1.8.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 233)) (1.8.1)
# Requirement already satisfied: tensorflow==2.9.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 234)) (2.9.2)
# Requirement already satisfied: tensorflow-estimator==2.9.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 235)) (2.9.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.30.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 236)) (0.30.0)
# Requirement already satisfied: tensorstore==0.1.30 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 237)) (0.1.30)
# Requirement already satisfied: termcolor==2.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 238)) (2.2.0)
# Requirement already satisfied: terminado==0.17.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 239)) (0.17.1)
# Requirement already satisfied: terminaltables==3.1.10 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 240)) (3.1.10)
# Requirement already satisfied: thinc==8.1.7 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 241)) (8.1.7)
# Requirement already satisfied: threadpoolctl==3.1.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 242)) (3.1.0)
# Requirement already satisfied: tifffile==2023.1.23.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 243)) (2023.1.23.1)
# Requirement already satisfied: tinycss2==1.2.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 244)) (1.2.1)
# Requirement already satisfied: tokenizers==0.12.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 245)) (0.12.1)
# Requirement already satisfied: tomli==2.0.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 246)) (2.0.1)
# Requirement already satisfied: toolz==0.12.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 247)) (0.12.0)
# Requirement already satisfied: torch==1.12.1+cu116 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 248)) (1.12.1+cu116)
# Requirement already satisfied: torchaudio==0.12.1+cu116 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 249)) (0.12.1+cu116)
# Requirement already satisfied: torchvision==0.13.1+cu116 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 250)) (0.13.1+cu116)
# Requirement already satisfied: tornado==6.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 251)) (6.1)
# Requirement already satisfied: tqdm==4.64.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 252)) (4.64.1)
# Requirement already satisfied: traitlets==5.8.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 253)) (5.8.1)
# Collecting transformers==4.40.1
#   Downloading transformers-4.40.1-py3-none-any.whl (9.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 54.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typer==0.4.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 255)) (0.4.2)
# Requirement already satisfied: typing_extensions==4.4.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 256)) (4.4.0)
# Requirement already satisfied: Unidecode==1.1.1 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 257)) (1.1.1)
# Requirement already satisfied: urllib3==1.26.14 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 258)) (1.26.14)
# Requirement already satisfied: wandb==0.13.4 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 259)) (0.13.4)
# Requirement already satisfied: wasabi==0.10.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 260)) (0.10.1)
# Requirement already satisfied: wcwidth==0.2.6 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 261)) (0.2.6)
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 262)) (0.5.1)
# Requirement already satisfied: websocket-client==0.57.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 263)) (0.57.0)
# Requirement already satisfied: Werkzeug==2.2.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 264)) (2.2.2)
# Requirement already satisfied: widgetsnbextension==4.0.5 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 265)) (4.0.5)
# Requirement already satisfied: wrapt==1.14.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 266)) (1.14.1)
# Requirement already satisfied: xgboost==1.6.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 267)) (1.6.2)
# Requirement already satisfied: xlrd==1.1.0 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 268)) (1.1.0)
# Requirement already satisfied: xxhash==3.2.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 269)) (3.2.0)
# Requirement already satisfied: yarl==1.8.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 270)) (1.8.2)
# Requirement already satisfied: zipp==3.11.0 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 271)) (3.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse==1.6.3->-r requirements.txt (line 13)) (0.35.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from jupyter-contrib-core==0.4.2->-r requirements.txt (line 105)) (66.1.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.9/dist-packages (from orbax==0.1.0->-r requirements.txt (line 154)) (7.4.4)
# Requirement already satisfied: pycairo>=1.11.1 in /usr/local/lib/python3.9/dist-packages (from PyGObject==3.36.0->-r requirements.txt (line 182)) (1.26.0)

# %% [markdown]
# # Init pipeline

# %%
import logging
import spacy_llm
from spacy_llm.util import assemble
from huggingface_hub import login
import os


# login(token=token)


# set log level to stream to STDOUT
spacy_llm.logger.addHandler(logging.StreamHandler())
spacy_llm.logger.setLevel(logging.DEBUG)


# nlp = spacy.load("en_core_web_md")
nlp = assemble("config.cfg")
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/593 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [22], line 17
#      13 spacy_llm.logger.setLevel(logging.DEBUG)
#      16 # nlp = spacy.load("en_core_web_md")
# ---> 17 nlp = assemble("config.cfg")
#
# File /usr/local/lib/python3.9/dist-packages/spacy_llm/util.py:48, in assemble(config_path, overrides)
#      46 config_path = Path(config_path)
#      47 config = load_config(config_path, overrides=overrides, interpolate=False)
# ---> 48 return assemble_from_config(config)
#
# File /usr/local/lib/python3.9/dist-packages/spacy_llm/util.py:28, in assemble_from_config(config)
#      22 def assemble_from_config(config: Config) -> Language:
#      23     """Assemble a spaCy pipeline from a confection Config object.
#      24
#      25     config (Config): Config to load spaCy pipeline from.
#      26     RETURNS (Language): An initialized spaCy pipeline.
#      27     """
# ---> 28     nlp = load_model_from_config(config, auto_fill=True)
#      29     config = config.interpolate()
#      30     sourced = get_sourced_components(config)
#
# File /usr/local/lib/python3.9/dist-packages/spacy/util.py:554, in load_model_from_config(config, meta, vocab, disable, enable, exclude, auto_fill, validate)
#     551 # This will automatically handle all codes registered via the languages
#     552 # registry, including custom subclasses provided via entry points
#     553 lang_cls = get_lang_class(nlp_config["lang"])
# --> 554 nlp = lang_cls.from_config(
#     555     config,
#     556     vocab=vocab,
#     557     disable=disable,
#     558     enable=enable,
#     559     exclude=exclude,
#     560     auto_fill=auto_fill,
#     561     validate=validate,
#     562     meta=meta,
#     563 )
#     564 return nlp
#
# File /usr/local/lib/python3.9/dist-packages/spacy/language.py:1803, in Language.from_config(cls, config, vocab, disable, enable, exclude, meta, auto_fill, validate)
#    1800     factory = pipe_cfg.pop("factory")
#    1801     # The pipe name (key in the config) here is the unique name
#    1802     # of the component, not necessarily the factory
# -> 1803     nlp.add_pipe(
#    1804         factory,
#    1805         name=pipe_name,
#    1806         config=pipe_cfg,
#    1807         validate=validate,
#    1808         raw_config=raw_config,
#    1809     )
#    1810 else:
#    1811     # We need the sourced components to reference the same
#    1812     # vocab without modifying the current vocab state **AND**
#    (...)
#    1817     # during deserialization, so they do not need any
#    1818     # additional handling.
#    1819     if vocab_b is None:
#
# File /usr/local/lib/python3.9/dist-packages/spacy/language.py:786, in Language.add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     782     pipe_component, factory_name = self.create_pipe_from_source(
#     783         factory_name, source, name=name
#     784     )
#     785 else:
# --> 786     pipe_component = self.create_pipe(
#     787         factory_name,
#     788         name=name,
#     789         config=config,
#     790         raw_config=raw_config,
#     791         validate=validate,
#     792     )
#     793 pipe_index = self._get_pipe_index(before, after, first, last)
#     794 self._pipe_meta[name] = self.get_factory_meta(factory_name)
#
# File /usr/local/lib/python3.9/dist-packages/spacy/language.py:679, in Language.create_pipe(self, factory_name, name, config, raw_config, validate)
#     676 cfg = {factory_name: config}
#     677 # We're calling the internal _fill here to avoid constructing the
#     678 # registered functions twice
# --> 679 resolved = registry.resolve(cfg, validate=validate)
#     680 filled = registry.fill({"cfg": cfg[factory_name]}, validate=validate)["cfg"]
#     681 filled = Config(filled)
#
# File /usr/local/lib/python3.9/dist-packages/confection/__init__.py:759, in registry.resolve(cls, config, schema, overrides, validate)
#     750 @classmethod
#     751 def resolve(
#     752     cls,
#    (...)
#     757     validate: bool = True,
#     758 ) -> Dict[str, Any]:
# --> 759     resolved, _ = cls._make(
#     760         config, schema=schema, overrides=overrides, validate=validate, resolve=True
#     761     )
#     762     return resolved
#
# File /usr/local/lib/python3.9/dist-packages/confection/__init__.py:808, in registry._make(cls, config, schema, overrides, resolve, validate)
#     806 if not is_interpolated:
#     807     config = Config(orig_config).interpolate()
# --> 808 filled, _, resolved = cls._fill(
#     809     config, schema, validate=validate, overrides=overrides, resolve=resolve
#     810 )
#     811 filled = Config(filled, section_order=section_order)
#     812 # Check that overrides didn't include invalid properties not in config
#
# File /usr/local/lib/python3.9/dist-packages/confection/__init__.py:863, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     861     schema.__fields__[key] = copy_model_field(field, Any)
#     862 promise_schema = cls.make_promise_schema(value, resolve=resolve)
# --> 863 filled[key], validation[v_key], final[key] = cls._fill(
#     864     value,
#     865     promise_schema,
#     866     validate=validate,
#     867     resolve=resolve,
#     868     parent=key_parent,
#     869     overrides=overrides,
#     870 )
#     871 reg_name, func_name = cls.get_constructor(final[key])
#     872 args, kwargs = cls.parse_args(final[key])
#
# File /usr/local/lib/python3.9/dist-packages/confection/__init__.py:880, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     877     getter = cls.get(reg_name, func_name)
#     878     # We don't want to try/except this and raise our own error
#     879     # here, because we want the traceback if the function fails.
# --> 880     getter_result = getter(*args, **kwargs)
#     881 else:
#     882     # We're not resolving and calling the function, so replace
#     883     # the getter_result with a Promise class
#     884     getter_result = Promise(
#     885         registry=reg_name, name=func_name, args=args, kwargs=kwargs
#     886     )
#
# File /usr/local/lib/python3.9/dist-packages/spacy_llm/models/hf/openllama.py:108, in openllama_hf(name, config_init, config_run)
#      95 @registry.llm_models("spacy.OpenLLaMA.v1")
#      96 def openllama_hf(
#      97     name: OpenLLaMA.MODEL_NAMES,
#      98     config_init: Optional[Dict[str, Any]] = SimpleFrozenDict(),
#      99     config_run: Optional[Dict[str, Any]] = SimpleFrozenDict(),
#     100 ) -> Callable[[Iterable[Iterable[str]]], Iterable[Iterable[str]]]:
#     101     """Generates OpenLLaMA instance that can execute a set of prompts and return the raw responses.
#     102     name (Literal): Name of the OpenLLaMA model. Has to be one of OpenLLaMA.get_model_names().
#     103     config_init (Optional[Dict[str, Any]]): HF config for initializing the model.
#    (...)
#     106         the raw responses.
#     107     """
# --> 108     return OpenLLaMA(
#     109         name=name, config_init=config_init, config_run=config_run, context_length=2048
#     110     )
#
# File /usr/local/lib/python3.9/dist-packages/spacy_llm/models/hf/openllama.py:26, in OpenLLaMA.__init__(self, name, config_init, config_run, context_length)
#      18 def __init__(
#      19     self,
#      20     name: str,
#    (...)
#      23     context_length: Optional[int],
#      24 ):
#      25     self._tokenizer: Optional["transformers.AutoTokenizer"] = None
# ---> 26     super().__init__(
#      27         name=name,
#      28         config_init=config_init,
#      29         config_run=config_run,
#      30         context_length=context_length,
#      31     )
#
# File /usr/local/lib/python3.9/dist-packages/spacy_llm/models/hf/base.py:75, in HuggingFace.__init__(self, name, config_init, config_run, context_length)
#      73 HuggingFace.check_installation()
#      74 self._check_model()
# ---> 75 self._model = self.init_model()
#
# File /usr/local/lib/python3.9/dist-packages/spacy_llm/models/hf/openllama.py:38, in OpenLLaMA.init_model(self)
#      34 """Sets up HF model and needed utilities.
#      35 RETURNS (Any): HF model.
#      36 """
#      37 # Initialize tokenizer and model.
# ---> 38 self._tokenizer = transformers.AutoTokenizer.from_pretrained(self._name)
#      39 init_cfg = self._config_init
#      40 device: Optional[str] = None
#
# File /usr/local/lib/python3.9/dist-packages/transformers/models/auto/tokenization_auto.py:588, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     585         tokenizer_class = tokenizer_class_from_name(tokenizer_class_candidate)
#     587     if tokenizer_class is None:
# --> 588         raise ValueError(
#     589             f"Tokenizer class {tokenizer_class_candidate} does not exist or is not currently imported."
#     590         )
#     591     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     593 # Otherwise we have to be creative.
#     594 # if model is an encoder decoder, the encoder tokenizer class is used by default
#
# ValueError: Tokenizer class LlamaTokenizer does not exist or is not currently imported.

# %% [markdown]
# ### Perform NER and relations

# %%
import os
from time import sleep
import pandas as pd






if os.path.exists('entities.pkl') and os.path.exists('relations.pkl'):
    with open('entities.pkl', 'rb') as f:
        entities_df = pd.read_pickle(f)
    with open('relations.pkl', 'rb') as f:
        relations_df = pd.read_pickle(f)
    
else:
    docs_df = get_data()
    docs = docs_df[0].tolist()
    
    
    entities_rows = []
    relations_rows = []
    for doc in tqdm(docs):
        enriched_doc = nlp(doc)
        sleep(1) # sleep for openai
        ents = enriched_doc.ents
        for ent in ents:
            entities_rows.append({"name": ent.text, "label": ent.label_, "fact": doc})  # type: ignore
        for rel in enriched_doc._.rel:
            dep_name = ents[rel.dep].text
            dep_label = ents[rel.dep].label_
            dest_name = ents[rel.dest].text
            dest_label = ents[rel.dest].label_

            # ignore self relations
            if (dep_name, dep_label) == (dest_name, dest_label):
                continue

            # ignore dates
            if dep_label == "DATE" or dest_label == "DATE":
                continue

            relations_rows.append(
                {
                    "dep_name": dep_name,
                    "dep_label": dep_label,
                    "dest_name": dest_name,
                    "dest_label": dest_label,
                    "rel": rel.relation,
                    "fact": doc,
                }
            )


    entities_df = pd.DataFrame(entities_rows)
    relations_df = pd.DataFrame(relations_rows)

    with open('entities.pkl', 'wb') as f:
        entities_df.to_pickle(f)
        
    with open('relations.pkl', 'wb') as f:
        relations_df.to_pickle(f)

# %% [markdown]
# ### Resolve inconsistencies

# %%
# group facts from entities
grouped_entities_df = entities_df.groupby(["name", "label"]).agg({"fact": lambda x: list(x)}).reset_index()
grouped_relations_df = (
    relations_df.groupby(["dep_name", "dep_label", "dest_name", "dest_label", "rel"]).agg({"fact": lambda x: list(x)}).reset_index()
)


# in some passes, a subset of the labels should be discarded
# perhaps, characterize the convo by work, personal, etc and tailor retrieval accordingly

# clashing entity types
labels_grouped = grouped_entities_df.groupby(["name"]).agg({"label": lambda x: list(x), "fact": lambda x: [item for sublist in x for item in sublist]}).reset_index()
clashing_entity_labels = labels_grouped[labels_grouped["label"].apply(lambda x: len(x) > 1)]


rels_grouped = grouped_relations_df.groupby(["dep_name", "dest_name"]).agg({"rel": lambda x: list(x), "fact": lambda x: [item for sublist in x for item in sublist]}).reset_index()
clashing_rels = rels_grouped[rels_grouped["rel"].apply(lambda x: len(x) > 1)]

# %%
import os
import huggingface_hub
import outlines.models.openai
from pandas import Series
# resolve entities
import outlines
import outlines.models
from pandas import Series
huggingface_hub.login(token=os.environ['HF_TOKEN'])
# model = outlines.models.openai("gpt-3.5-turbo") 
# model = outlines.models.openai("gpt-4-0613")
model = outlines.models.transformers("mistralai/Mistral-7B-Instruct-v0.2", device='mps')
# model = outlines.models.llamacpp("TheBloke/phi-2-GGUF", "phi-2.Q4_K_M.gguf", device='mps')


def pick_winning_label(row: Series) -> str:
    print('processing a request after 5 sec delay')
    sleep(5)
    labels = row["label"]
    name = row["name"]
    facts = "\n".join(row["fact"])

    prompt = f"""You are an entity resolution assistant. 
    You must classify the entity with name = {name}
    
    Use both your inherent knowledge, and these facts derived from chat logs:
    {facts} 
    """

    generator = outlines.generate.choice(model, labels)
    answer = generator(prompt)
    print(f"{name}: Choices = {labels}. WINNER = {answer}")
    return answer


new_df = clashing_entity_labels.apply(pick_winning_label, axis=1)
